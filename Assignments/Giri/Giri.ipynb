# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/IBM/data/House Price India.csv")
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.dropna(inplace=True)

# %%
sns.countplot(x="number of bedrooms",data=df)
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
sns.countplot(x="number of bathrooms",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x="waterfront present",data=df)
# Out:
# <Axes: xlabel='waterfront present', ylabel='count'>

# %%
sns.countplot(x="condition of the house",data=df)
# Out:
# <Axes: xlabel='condition of the house', ylabel='count'>

# %%
sns.countplot(x="Number of schools nearby",data=df)
# Out:
# <Axes: xlabel='Number of schools nearby', ylabel='count'>

# %%
sns.countplot(x="number of views",data=df)
# Out:
# <Axes: xlabel='number of views', ylabel='count'>

# %%
plt.subplot(2,1,1)
sns.histplot(x="grade of the house",data=df)
plt.subplot(2,1,2)
sns.histplot(x="Price",data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))
sns.barplot(x="grade of the house",y="Price",data=df,ax=axes[0,0])
sns.barplot(x="condition of the house",y="Price",data=df,ax=axes[0,1])
sns.barplot(x="number of bedrooms",y="Price",data=df,ax=axes[1,0])
sns.barplot(x="number of bathrooms",y="Price",data=df,ax=axes[1,1])
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='Price'>

# %%
sns.barplot(y="grade of the house",x="condition of the house",data=data)
# Out:
# <Axes: xlabel='condition of the house', ylabel='grade of the house'>

# %%
data=df.iloc[:,[7,8,9,10,20,22]]
data.head()
# Out:
#    waterfront present  number of views  condition of the house  \
# 0                   0                4                       5
# 1                   0                0                       5
# 2                   0                0                       3
# 3                   0                0                       3
# 4                   0                0                       4
#
#    grade of the house  Number of schools nearby    Price
# 0                  10                         2  2380000
# 1                   8                         2  1400000
# 2                   8                         1  1200000
# 3                   9                         3   838000
# 4                   8                         1   805000

# %%
sns.pairplot(data,diag_kind="kde")

# %%
sns.pairplot(data,hue="number of views")

# %%
sns.heatmap(data=data.corr(),annot=True,cmap="plasma")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=data,x="grade of the house",y="Price",hue="waterfront present",palette="mako")
# Out:
# <Axes: xlabel='grade of the house', ylabel='Price'>

# %%
data.describe().transpose()
# Out:
#                             count           mean            std      min  \
# waterfront present        14620.0       0.007661       0.087193      0.0
# number of views           14620.0       0.233105       0.766259      0.0
# condition of the house    14620.0       3.430506       0.664151      1.0
# grade of the house        14620.0       7.682421       1.175033      4.0
# Number of schools nearby  14620.0       2.012244       0.817284      1.0
# Price                     14620.0  538932.218331  367532.380804  78000.0
#
#                                25%       50%       75%        max
# waterfront present             0.0       0.0       0.0        1.0
# number of views                0.0       0.0       0.0        4.0
# condition of the house         3.0       3.0       4.0        5.0
# grade of the house             7.0       7.0       8.0       13.0
# Number of schools nearby       1.0       2.0       3.0        3.0
# ...
